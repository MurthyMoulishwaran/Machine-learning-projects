# %%
import pandas as pd

# %%
df=pd.read_csv(r"E:\illustrator\archive (19)\Bank Customer Churn Prediction.csv")
df.head(10)
# Out:
#    customer_id  credit_score  country  gender  age  tenure    balance  \
# 0     15634602           619   France  Female   42       2       0.00
# 1     15647311           608    Spain  Female   41       1   83807.86
# 2     15619304           502   France  Female   42       8  159660.80
# 3     15701354           699   France  Female   39       1       0.00
# 4     15737888           850    Spain  Female   43       2  125510.82
# 5     15574012           645    Spain    Male   44       8  113755.78
# 6     15592531           822   France    Male   50       7       0.00
# 7     15656148           376  Germany  Female   29       4  115046.74
# 8     15792365           501   France    Male   44       4  142051.07
# 9     15592389           684   France    Male   27       2  134603.88
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# ...

# %%
df.isnull().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
from sklearn.preprocessing import LabelEncoder
encode = LabelEncoder()

# %%
df["gender"]=encode.fit_transform(df["gender"])
df["country"]=encode.fit_transform(df["country"])
df.head(10)
# Out:
#    customer_id  credit_score  country  gender  age  tenure    balance  \
# 0     15634602           619        0       0   42       2       0.00
# 1     15647311           608        2       0   41       1   83807.86
# 2     15619304           502        0       0   42       8  159660.80
# 3     15701354           699        0       0   39       1       0.00
# 4     15737888           850        2       0   43       2  125510.82
# 5     15574012           645        2       1   44       8  113755.78
# 6     15592531           822        0       1   50       7       0.00
# 7     15656148           376        1       0   29       4  115046.74
# 8     15792365           501        0       1   44       4  142051.07
# 9     15592389           684        0       1   27       2  134603.88
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# ...

# %%
#dummies = pd.get_dummies(df['gender'],drop_first=True)
#dummies

# %%
#dum = pd.get_dummies(df['country'],drop_first=True)
#dum

# %%
#df1 = pd.concat([df, dummies,dum], axis=1)
#df1

# %%
#Df=df1.drop(['gender','country'],axis=1)
#Df

# %%
count = (df["churn"] == 1).sum()
count2 = (df["churn"] == 0).sum()
print(count,count2)
# Out:
# 2037 7963

# %%
x = df[['credit_score','tenure','age','gender','country','credit_card','active_member']]
y = df.churn

# %%
from sklearn.model_selection import train_test_split as tts

# %%
x_train,x_test,y_train,y_test=tts(x,y,test_size=0.3,random_state=20)
x_train
# Out:
#       credit_score  tenure  age  gender  country  credit_card  active_member
# 8094           614       2   66       1        2            0              1
# 1008           444       6   45       1        0            1              0
# 8016           569       2   41       1        2            1              0
# 1964           800       5   40       0        0            1              0
# 9844           658       5   40       0        0            1              1
# ...            ...     ...  ...     ...      ...          ...            ...
# 3915           686       2   43       1        1            1              1
# 9620           561       4   37       1        2            0              1
# 7068           699       3   54       0        1            1              1
# 7391           430       5   31       1        0            1              0
# 4367           573       0   50       1        2            0              1
#
# [7000 rows x 7 columns]

# %%
##svm_classifier = SVC(kernel='linear')

# %%
from sklearn.svm import SVC

# %%
svc=SVC()
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
pre=svc.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pre))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.89      2423
#            1       0.00      0.00      0.00       577
#
#     accuracy                           0.81      3000
#    macro avg       0.40      0.50      0.45      3000
# weighted avg       0.65      0.81      0.72      3000
# C:\Users\Moulishwaran\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Moulishwaran\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
param_grid = {'C': [0.1,1, 10, 100, 1000], 'gamma': [1,0.1,0.01,0.001,0.0001], 'kernel': ['rbf']}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=3)
grid
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.791 total time=   2.3s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.791 total time=   1.8s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.791 total time=   1.5s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.791 total time=   1.7s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.791 total time=   1.5s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.791 total time=   1.3s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.791 total time=   1.6s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.791 total time=   1.4s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.791 total time=   1.7s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.791 total time=   1.4s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.791 total time=   0.5s
# ...

# %%
grid.best_params_
# Out:
# {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
grid.best_estimator_
# Out:
# SVC(C=1000, gamma=0.001)

# %%
grid_predictions = grid.predict(x_test)

# %%
print(classification_report(y_test,grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.90      2423
#            1       0.65      0.27      0.38       577
#
#     accuracy                           0.83      3000
#    macro avg       0.75      0.62      0.64      3000
# weighted avg       0.81      0.83      0.80      3000
